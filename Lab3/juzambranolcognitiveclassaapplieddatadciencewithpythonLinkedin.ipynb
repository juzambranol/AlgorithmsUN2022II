# %% [markdown]
# <a href="https://colab.research.google.com/github/juzambranol/AlgorithmsUN2022II/blob/main/Lab3/juzambranolcognitiveclassaapplieddatadciencewithpythonLinkedin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linkedin:
# https://www.linkedin.com/in/juan-camilo-zambrano-lopez-472a7424b/
# ![image.png](data:image/png;base64,...)
